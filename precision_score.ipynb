# %%
from tqdm import tqdm
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pymysql
import os
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler, LabelEncoder,StandardScaler
from sklearn.metrics import precision_score

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten,CuDNNLSTM, LSTM,RepeatVector
from keras.layers import TimeDistributed,Dropout, LeakyReLU, ReLU , BatchNormalization
from keras.layers.convolutional import Conv1D, MaxPooling1D
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.optimizers import RMSprop, Adam,SGD
from tensorflow.keras.models import load_model

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
db_daesin = pymysql.connect(host='221.148.138.91', port=3306, user='remote', password='1234', db='dbstock')
cursor_daesin = db_daesin.cursor()
cursor_daesin.execute('use dbstock;')

db_kiwoom = pymysql.connect(host='61.77.150.183', port=3306, user='a1_user',password='4560',db='kiwoom',charset='utf8')
cursor_kiwoom = db_kiwoom.cursor()
cursor_kiwoom.execute('use kiwoom;')
# Out:
# 0

# %%
def make_folder():
    
    folders = ['./csv','./csv/raw','./csv/filtered','./numpy',
               './numpy/B','./numpy/C','./numpy/D',
               './numpy/E','./numpy/concat','./model']
    
    for names in folders :
        
        if not os.path.exists(names):
            os.mkdir(names)           


def extract_dates(path = 'raw'):
    
#     path = './csv'
    file_list = os.listdir('./csv/'+ path)
    
    date_list = []
    for i in file_list:
        
        date_list.append(i.split('_')[0])
    
    return date_list

def daesin_main(code, date,db=db_daesin):    

    sql = 'select * from {};'.format(code)
    df_dae = pd.read_sql(sql, db)
    df_dae  = df_dae.set_index('체결시간')
    df_dae= df_dae[['매수잔량','매도잔량','체결강도']]
    df_dae = df_dae.loc[date]
    df_dae.drop(df_dae.between_time('15:20','15:29').index, inplace=True)
    df_dae.drop(df_dae.between_time('15:31','15:32').index, inplace=True)
    df_dae.drop(df_dae.at_time('23:59').index, inplace=True)
    
    
    return  df_dae

def daesin_kospi(date,db=db_daesin):  

    sql_kospi = 'select * from u001;'
    df_kospi = pd.read_sql(sql_kospi, db)
    df_kospi = df_kospi.set_index('체결시간')[['코스피지수']]

    df_kospi= df_kospi.loc[date]
    df_kospi.drop(df_kospi.between_time('15:20','15:29').index, inplace=True)
    df_kospi.drop(df_kospi.between_time('15:31','15:32').index, inplace=True)
    df_kospi.drop(df_kospi.at_time('23:59').index, inplace=True)    
    globals()['df_kospi_{}'.format(date.replace('-',''))] = df_kospi

    return globals()['df_kospi_{}'.format(date.replace('-',''))]


def daesin_issued(code,db=db_daesin):
    
    code2 = code.replace(code[0], code[0].upper())
    sql_issued = 'select * from z001;'
    df_issued = pd.read_sql(sql_issued, db)
    df_issued=  df_issued[df_issued.종목코드 == code2][['발행주식수']]
    
    globals()['{}_issued'.format(code)] = df_issued.values[0][0]
    
    return globals()['{}_issued'.format(code)]  

def kiwoom(code, date,db=db_kiwoom) : 
    
    sql_kiwoom = 'select * from {};'.format(code)
    df_kiwoom = pd.read_sql(sql_kiwoom, db)
    df_kiwoom  = df_kiwoom.set_index('체결시간')
    df_kiwoom= df_kiwoom.loc[date]
    df_kiwoom.rename(columns={'현재가':'종가'},inplace=True)
    df_kiwoom.drop('누적거래대금', axis=1, inplace=True)

    return df_kiwoom

def merge_df(date):
    
    df_dae, df_kiwoom, df_kospi= daesin_main(code, date,db=db_daesin),kiwoom(code, date,db=db_kiwoom), globals()['df_kospi_{}'.format(date.replace('-',''))]
    
    df_stock_temp = pd.merge(df_dae, df_kiwoom, left_index = True, right_index=True, how='inner')
    df_stock = pd.merge(df_stock_temp,df_kospi,
                        left_index = True, right_index=True, how='inner')
    df_stock = df_stock.apply(lambda x : abs(x))
    merged_df = df_stock.copy()
    
    return merged_df


def preprocessing(code, date):
    
    merged_df = merge_df(date)
    issued =  globals()['{}_issued'.format(code)]
    
    merged_df['매수잔량'] = (merged_df['매수잔량']/issued)*100
    merged_df['매도잔량'] = (merged_df['매도잔량']/issued)*100
    merged_df['거래량'] = (merged_df['거래량']/issued)*100
    merged_df.loc[date + ' 15:30:00', '거래량'] = merged_df.at_time('15:30')['거래량'].values[0]/10

    merged_df['코스피지수'] = merged_df['코스피지수'].pct_change()
    merged_df['시가'] = merged_df['시가'].pct_change()
    merged_df['고가'] = merged_df['고가'].pct_change()
    merged_df['저가'] = merged_df['저가'].pct_change()
    
    drop_index = merged_df[(merged_df['체결강도']== 0)|(merged_df['매수잔량']== 0)|(merged_df['체결강도']== 0)].index
    merged_df.drop(drop_index, axis=0,inplace=True)
    
    merged_df.insert(3,'체결강도_pct',merged_df['체결강도'].pct_change())
    merged_df.insert(1,'매수잔량_pct',merged_df['매수잔량'].pct_change())
    merged_df.insert(3,'매도잔량_pct',merged_df['매도잔량'].pct_change())
    merged_df.insert(7,'거래량_pct',merged_df['거래량'].pct_change())
    merged_df.insert(10,'종가_pct', merged_df['종가'].pct_change())

    
    merged_df.rename(columns = {'시가' : '시가_pct','고가' : '고가_pct','저가' : '저가_pct','코스피지수' : '코스피_pct'},inplace=True)
    
    merged_df.dropna(axis=0, inplace=True)

    merged_df.insert(0, 'time_section', merged_df.index)
    merged_df.loc[merged_df.between_time('09:00','10:30').index, 'time_section'] = '09:00~10:30'
    merged_df.loc[merged_df.between_time('10:31','13:59').index, 'time_section'] = '10:31~13:59'
    merged_df.loc[merged_df.between_time('14:00','15:30').index, 'time_section'] = '14:00~15:30'
    
#     scaler = MinMaxScaler()
#     merged_df[['매수잔량','매수잔량_pct','매도잔량','매도잔량_pct','체결강도_pct','체결강도','거래량_pct']] = scaler.fit_transform(merged_df[['매수잔량',
#                                                                                                                    '매수잔량_pct','매도잔량','매도잔량_pct',
#                                                                                                                    '체결강도_pct','체결강도','거래량_pct']])
   
    
#     scaler = StandardScaler()
#     merged_df[['매수잔량','매수잔량_pct','매도잔량','매도잔량_pct','체결강도_pct','체결강도','거래량_pct']] = scaler.fit_transform(merged_df[['매수잔량',
#                                                                                                                    '매수잔량_pct','매도잔량','매도잔량_pct',
#                                                                                                                    '체결강도_pct','체결강도','거래량_pct']])
    merged_df.drop(merged_df[merged_df['매수잔량_pct']==np.inf].index, axis=0, inplace=True)
    merged_df.drop(merged_df[merged_df['매도잔량_pct']==np.inf].index, axis=0, inplace=True)
    
    
    merged_df.drop(['매수잔량','매도잔량','체결강도'], axis=1, inplace=True)
    merged_df.drop(['시가_pct','고가_pct','저가_pct'], axis=1, inplace=True)
    
#     merged_df = pd.get_dummies(merged_df)

    merged_df.drop('time_section',axis=1,inplace=True)
    
    merged_df['target'] = merged_df['종가'].pct_change(periods=offset)
    merged_df.drop('종가', axis=1, inplace=True)
    

    for i in merged_df.index:
        if merged_df.loc[i,'target'] >=0 :
            merged_df.loc[i,'target'] = 'PLUS'
        else :
            merged_df.loc[i,'target'] = 'MINUS'

    
    return merged_df

def split_sequence(timesteps, offset):
    
    sequence = preprocessing(code, date)
    
    x, y = list(), list()
    
    target = 'target'
    
    for i in range(len(sequence)):
        
        end_ix = i + timesteps
        
        if end_ix > len(sequence) -offset:
            break
            
        seq_x, seq_y = sequence.drop(target,axis=1).iloc[i:end_ix], sequence.iloc[end_ix + offset-1][target]
        
        x.append(seq_x)
        y.append(seq_y)
        
        
        
    return np.array(x), np.array(y)

def train_test_split():
    
    x, y = split_sequence(timesteps, offset)
    
    e = LabelEncoder()
    e.fit(y)
    y = e.transform(y)
   
    
    cutoff_rate=0.8
    cutoff_train = round(x.shape[0] * cutoff_rate)

    x_train, y_train = x[:cutoff_train], y[:cutoff_train]
    x_test, y_test = x[cutoff_train:], y[cutoff_train:]
    
    return x_train, y_train, x_test, y_test


def filter_csv(timesteps, offset):
    
    date_list = extract_dates(path = 'raw')
    
    for date in date_list :
        
        df_raw = pd.read_csv('./csv/raw/{}_merged_groupping.csv'.format(date), index_col=0)
        raw_code_list = df_raw['종목코드']
        df_raw = df_raw.set_index('종목코드')

        filtered_code_list = []

        for code in raw_code_list :
            df_kiwoom = kiwoom(code, date)

            if len(df_kiwoom)-timesteps-offset >= 180:
                filtered_code_list.append(code)
    #             print(code)

        df_filtered =df_raw.loc[filtered_code_list]
        df_filtered.to_csv('./csv/filtered/{}_filtered_groupping.csv'.format(date)) 
    
    return df_filtered

def make_group(date):
    
    
    df_group = pd.read_csv('./csv/filtered/{}_filtered_groupping.csv'.format(date), index_col=0)

    B_code_list = df_group[df_group.그룹 == 'B'].index.to_list()
    C_code_list = df_group[df_group.그룹 == 'C'].index.to_list()
    D_code_list = df_group[df_group.그룹 == 'D'].index.to_list()
    E_code_list = df_group[df_group.그룹 == 'E'].index.to_list()

    return B_code_list, C_code_list,D_code_list,E_code_list


def concat_train_test(code_list):
    global code
        
    for i, code in (enumerate(code_list)) :
        
        try :
        
            if i == 0: 
                x_train0, y_train0, x_test0, y_test0 = train_test_spilt()

            else :
                x_train, y_train, x_test, y_test = train_test_spilt()
                
                x_train0 = tf.concat([x_train0, x_train], axis=0)
                y_train0 = tf.concat([y_train0, y_train], axis=0)
                x_test0 = tf.concat([x_test0, x_test], axis=0)
                y_test0 = tf.concat([y_test0, y_test], axis=0)
                
                x_train_concat = x_train0
                y_train_concat = y_train0
                x_test_concat = x_test0
                y_test_concat = y_test0
                
                print('정상', i,'/',len(code_list)-1, code)
                
        except Exception as ex:
            print(ex, code)
            
           
    return x_train_concat, y_train_concat, x_test_concat, y_test_concat 


def load_final_data(path = './numpy/concat/',group = None ,offset=None, timesteps=None):

    dataset_load=np.load(path+'final_{}_dataset_{}_{}.npz'.format(group,timesteps,offset))

    x_train=dataset_load['x_train']
    x_test=dataset_load['x_test']
    y_train=dataset_load['y_train']
    y_test=dataset_load['y_test']

    dataset_load.close()
    
    
    return x_train,x_test,y_train,y_test

def Standardscale(x_train, x_test, y_train, y_test):

    x_train = x_train.reshape(x_train.shape[0],-1)
    x_test = x_test.reshape(x_test.shape[0],-1)
    
    scaler = StandardScaler()
    scaler.fit(x_train)
    x_train_scaled = scaler.transform(x_train)
    x_test_scaled = scaler.transform(x_test)
    
    return x_train_scaled,x_test_scaled

# %%
def group_precision_score(date):
    
    daesin_kospi(date)
    
    group_list=['B','C','D','E']
    B_code_list, C_code_list,D_code_list,E_code_list = make_group(date)
    
    for group_name, code_list in zip(group_list,[B_code_list, C_code_list, D_code_list,E_code_list]):
        
        global code
        print(group_name, 'group start')  
        
        precision_list= list()
        model = load_model('./model/{}/{}_60_5_final.hdf5'.format(group_name,group_name))
        
        for i, code in enumerate(code_list) : 
            
            daesin_issued(code)
            
            x ,y = split_sequence(timesteps, offset)
            x = x.reshape(x.shape[0],-1)
            e = LabelEncoder()
            y = e.fit_transform(y)
            y= y.astype('float64')

            
            y_pred = np.where(model.predict(x)>0.5, 1,0)
            precision = round(precision_score(y, y_pred),3)
            precision_list.append(precision)
            
            print( i, '/', len(code_list)  , code,   'precision_score : ', precision)
            
        globals()['{}_precision_score'.format(group_name)] = np.mean(precision_list) 
        print(globals()['{}_precision_score'.format(group_name)])
        print()
        print(group_name, 'group done')    
        print()
        
        
    return globals()['{}_precision_score'.format(group_name)]

# %%
date = '2021-12-30'
timesteps=60
offset=5
group_precision_score(date)
# Out:
# B group start
# 0 / 14 a001440 precision_score :  0.747
# 1 / 14 a004830 precision_score :  0.769
# 2 / 14 a009680 precision_score :  0.808
# 3 / 14 a010820 precision_score :  0.66
# 4 / 14 a011200 precision_score :  0.709
# 5 / 14 a018470 precision_score :  0.756
# 6 / 14 a020560 precision_score :  0.737
# 7 / 14 a024890 precision_score :  0.648
# 8 / 14 a069620 precision_score :  0.681
# 9 / 14 a084680 precision_score :  0.613
# 10 / 14 a090350 precision_score :  0.689
# 11 / 14 a092200 precision_score :  0.59
# 12 / 14 a129260 precision_score :  0.698
# 13 / 14 a383220 precision_score :  0.617
# 0.6944285714285715
#
# B group done
#
# C group start
# 0 / 375 a000020 precision_score :  0.725
# 1 / 375 a000080 precision_score :  0.714
# 2 / 375 a000100 precision_score :  0.724
# 3 / 375 a000120 precision_score :  0.75
# 4 / 375 a000140 precision_score :  0.76
# 5 / 375 a000150 precision_score :  0.783
# 6 / 375 a000210 precision_score :  0.686
# 7 / 375 a000230 precision_score :  0.727
# 8 / 375 a000240 precision_score :  0.762
# 9 / 375 a000270 precision_score :  0.678
# 10 / 375 a000300 precision_score :  0.715
# 11 / 375 a000370 precision_score :  0.696
# 12 / 375 a000390 precision_score :  0.546
# 13 / 375 a000430 precision_score :  0.75
# 14 / 375 a000490 precision_score :  0.822
# 15 / 375 a000680 precision_score :  0.74
# 16 / 375 a000700 precision_score :  0.701
# 17 / 375 a000720 precision_score :  0.753
# 18 / 375 a000810 precision_score :  0.729
# 19 / 375 a000860 precision_score :  0.608
# 20 / 375 a000880 precision_score :  0.72
# 21 / 375 a000910 precision_score :  0.584
# 22 / 375 a000990 precision_score :  0.68
# 23 / 375 a001040 precision_score :  0.701
# 24 / 375 a001120 precision_score :  0.764
# 25 / 375 a001140 precision_score :  0.624
# 26 / 375 a001230 precision_score :  0.711
# 27 / 375 a001250 precision_score :  0.739
# 28 / 375 a001340 precision_score :  0.699
# 29 / 375 a001360 precision_score :  0.697
# 30 / 375 a001430 precision_score :  0.738
# 31 / 375 a001450 precision_score :  0.68
# 32 / 375 a001510 precision_score :  0.783
# 33 / 375 a001520 precision_score :  0.776
# 34 / 375 a001530 precision_score :  0.669
# 35 / 375 a001680 precision_score :  0.742
# 36 / 375 a001740 precision_score :  0.765
# 37 / 375 a001780 precision_score :  0.715
# 38 / 375 a001800 precision_score :  0.761
# 39 / 375 a001940 precision_score :  0.702
# 40 / 375 a002020 precision_score :  0.672
# 41 / 375 a002200 precision_score :  0.85
# 42 / 375 a002310 precision_score :  0.762
# 43 / 375 a002320 precision_score :  0.729
# 44 / 375 a002350 precision_score :  0.708
# 45 / 375 a002380 precision_score :  0.763
# 46 / 375 a002420 precision_score :  0.685
# 47 / 375 a002460 precision_score :  0.753
# 48 / 375 a002690 precision_score :  0.817
# 49 / 375 a002700 precision_score :  0.747
# 50 / 375 a002780 precision_score :  0.677
# 51 / 375 a002790 precision_score :  0.69
# 52 / 375 a002880 precision_score :  0.76
# 53 / 375 a002900 precision_score :  0.703
# 54 / 375 a002990 precision_score :  0.838
# 55 / 375 a003000 precision_score :  0.779
# 56 / 375 a003010 precision_score :  0.737
# 57 / 375 a003090 precision_score :  0.667
# 58 / 375 a003160 precision_score :  0.586
# 59 / 375 a003220 precision_score :  0.746
# 60 / 375 a003230 precision_score :  0.631
# 61 / 375 a003280 precision_score :  0.65
# 62 / 375 a003410 precision_score :  0.741
# 63 / 375 a003490 precision_score :  0.693
# 64 / 375 a003540 precision_score :  0.691
# 65 / 375 a003550 precision_score :  0.713
# 66 / 375 a003560 precision_score :  0.751
# 67 / 375 a003670 precision_score :  0.784
# 68 / 375 a003780 precision_score :  0.582
# 69 / 375 a003850 precision_score :  0.775
# 70 / 375 a004000 precision_score :  0.671
# 71 / 375 a004020 precision_score :  0.69
# 72 / 375 a004170 precision_score :  0.775
# 73 / 375 a004250 precision_score :  0.768
# 74 / 375 a004310 precision_score :  0.744
# 75 / 375 a004370 precision_score :  0.715
# 76 / 375 a004410 precision_score :  0.734
# 77 / 375 a004430 precision_score :  0.747
# 78 / 375 a004490 precision_score :  0.686
# 79 / 375 a004560 precision_score :  0.753
# 80 / 375 a004800 precision_score :  0.66
# 81 / 375 a004870 precision_score :  0.541
# 82 / 375 a004920 precision_score :  0.625
# 83 / 375 a004990 precision_score :  0.734
# 84 / 375 a005010 precision_score :  0.842
# 85 / 375 a005070 precision_score :  0.676
# 86 / 375 a005090 precision_score :  0.664
# 87 / 375 a005110 precision_score :  0.789
# 88 / 375 a005250 precision_score :  0.754
# 89 / 375 a005300 precision_score :  0.719
# 90 / 375 a005320 precision_score :  0.567
# 91 / 375 a005380 precision_score :  0.711
# 92 / 375 a005420 precision_score :  0.7
# 93 / 375 a005440 precision_score :  0.683
# 94 / 375 a005490 precision_score :  0.712
# 95 / 375 a005500 precision_score :  0.782
# 96 / 375 a005680 precision_score :  0.757
# 97 / 375 a005810 precision_score :  0.62
# 98 / 375 a005850 precision_score :  0.657
# 99 / 375 a005870 precision_score :  0.598
# 100 / 375 a005880 precision_score :  0.689
# 101 / 375 a005940 precision_score :  0.816
# 102 / 375 a005950 precision_score :  0.789
# 103 / 375 a005960 precision_score :  0.739
# 104 / 375 a006060 precision_score :  0.667
# 105 / 375 a006110 precision_score :  0.686
# 106 / 375 a006120 precision_score :  0.595
# 107 / 375 a006200 precision_score :  0.662
# 108 / 375 a006220 precision_score :  0.702
# 109 / 375 a006280 precision_score :  0.77
# 110 / 375 a006340 precision_score :  0.825
# 111 / 375 a006360 precision_score :  0.649
# 112 / 375 a006390 precision_score :  0.628
# 113 / 375 a006400 precision_score :  0.692
# 114 / 375 a006490 precision_score :  0.63
# 115 / 375 a006650 precision_score :  0.739
# 116 / 375 a007070 precision_score :  0.695
# 117 / 375 a007110 precision_score :  0.701
# 118 / 375 a007120 precision_score :  0.713
# 119 / 375 a007160 precision_score :  0.695
# 120 / 375 a007210 precision_score :  0.653
# 121 / 375 a007460 precision_score :  0.736
# 122 / 375 a007690 precision_score :  0.643
# 123 / 375 a007700 precision_score :  0.665
# 124 / 375 a007860 precision_score :  0.741
# 125 / 375 a008350 precision_score :  0.696
# 126 / 375 a008420 precision_score :  0.605
# 127 / 375 a008490 precision_score :  0.667
# 128 / 375 a008560 precision_score :  0.709
# 129 / 375 a008600 precision_score :  0.755
# 130 / 375 a008770 precision_score :  0.69
# 131 / 375 a008930 precision_score :  0.617
# 132 / 375 a009070 precision_score :  0.659
# 133 / 375 a009150 precision_score :  0.725
# 134 / 375 a009160 precision_score :  0.592
# 135 / 375 a009180 precision_score :  0.665
# 136 / 375 a009190 precision_score :  0.57
# 137 / 375 a009240 precision_score :  0.608
# 138 / 375 a009270 precision_score :  0.584
# 139 / 375 a009290 precision_score :  0.677
# 140 / 375 a009420 precision_score :  0.748
# 141 / 375 a009450 precision_score :  0.771
# 142 / 375 a009540 precision_score :  0.671
# 143 / 375 a009830 precision_score :  0.74
# 144 / 375 a009900 precision_score :  0.7
# 145 / 375 a009970 precision_score :  0.646
# 146 / 375 a010060 precision_score :  0.799
# 147 / 375 a010120 precision_score :  0.706
# 148 / 375 a010130 precision_score :  0.646
# 149 / 375 a010140 precision_score :  0.718
# 150 / 375 a010640 precision_score :  0.658
# 151 / 375 a010690 precision_score :  0.669
# 152 / 375 a010780 precision_score :  0.618
# 153 / 375 a010950 precision_score :  0.653
# 154 / 375 a010960 precision_score :  0.792
# 155 / 375 a011070 precision_score :  0.598
# 156 / 375 a011090 precision_score :  0.673
# 157 / 375 a011150 precision_score :  0.604
# 158 / 375 a011170 precision_score :  0.697
# 159 / 375 a011210 precision_score :  0.695
# 160 / 375 a011420 precision_score :  0.605
# 161 / 375 a011700 precision_score :  0.682
# 162 / 375 a011780 precision_score :  0.708
# 163 / 375 a011790 precision_score :  0.768
# 164 / 375 a012030 precision_score :  0.702
# 165 / 375 a012330 precision_score :  0.658
# 166 / 375 a012450 precision_score :  0.595
# 167 / 375 a012610 precision_score :  0.722
# 168 / 375 a012630 precision_score :  0.769
# 169 / 375 a012750 precision_score :  0.681
# 170 / 375 a013570 precision_score :  0.635
# 171 / 375 a013580 precision_score :  0.653
# 172 / 375 a013890 precision_score :  0.63
# 173 / 375 a014160 precision_score :  0.701
# 174 / 375 a014280 precision_score :  0.797
# 175 / 375 a014580 precision_score :  0.697
# 176 / 375 a014680 precision_score :  0.721
# 177 / 375 a014790 precision_score :  0.705
# 178 / 375 a014820 precision_score :  0.72
# 179 / 375 a014830 precision_score :  0.815
# 180 / 375 a016090 precision_score :  0.802
# 181 / 375 a016360 precision_score :  0.68
# 182 / 375 a016380 precision_score :  0.781
# 183 / 375 a016580 precision_score :  0.851
# 184 / 375 a016740 precision_score :  0.714
# 185 / 375 a016880 precision_score :  0.731
# 186 / 375 a017040 precision_score :  0.714
# 187 / 375 a017550 precision_score :  0.682
# 188 / 375 a017670 precision_score :  0.68
# 189 / 375 a017800 precision_score :  0.697
# 190 / 375 a017810 precision_score :  0.692
# 191 / 375 a017940 precision_score :  0.876
# 192 / 375 a017960 precision_score :  0.801
# 193 / 375 a018260 precision_score :  0.707
# 194 / 375 a018880 precision_score :  0.744
# 195 / 375 a019170 precision_score :  0.667
# 196 / 375 a019180 precision_score :  0.61
# 197 / 375 a020000 precision_score :  0.698
# 198 / 375 a020120 precision_score :  0.754
# 199 / 375 a020150 precision_score :  0.744
# 200 / 375 a020760 precision_score :  0.763
# 201 / 375 a021240 precision_score :  0.592
# 202 / 375 a023530 precision_score :  0.755
# 203 / 375 a023590 precision_score :  0.7
# 204 / 375 a024110 precision_score :  0.775
# 205 / 375 a024720 precision_score :  0.777
# 206 / 375 a025540 precision_score :  0.675
# 207 / 375 a025620 precision_score :  0.694
# 208 / 375 a025750 precision_score :  0.842
# 209 / 375 a026960 precision_score :  0.809
# 210 / 375 a027410 precision_score :  0.787
# 211 / 375 a028100 precision_score :  0.741
# 212 / 375 a028670 precision_score :  0.699
# 213 / 375 a030000 precision_score :  0.63
# 214 / 375 a030200 precision_score :  0.687
# 215 / 375 a030210 precision_score :  0.601
# 216 / 375 a031430 precision_score :  0.735
# 217 / 375 a031440 precision_score :  0.7
# 218 / 375 a031820 precision_score :  0.702
# 219 / 375 a032350 precision_score :  0.749
# 220 / 375 a032640 precision_score :  0.782
# 221 / 375 a032830 precision_score :  0.671
# 222 / 375 a033180 precision_score :  0.665
# 223 / 375 a033240 precision_score :  0.648
# 224 / 375 a033780 precision_score :  0.722
# 225 / 375 a034020 precision_score :  0.737
# 226 / 375 a034120 precision_score :  0.719
# 227 / 375 a034220 precision_score :  0.763
# 228 / 375 a034310 precision_score :  0.76
# 229 / 375 a034730 precision_score :  0.703
# 230 / 375 a035000 precision_score :  0.788
# 231 / 375 a035150 precision_score :  0.629
# 232 / 375 a035250 precision_score :  0.769
# 233 / 375 a035420 precision_score :  0.75
# 234 / 375 a035720 precision_score :  0.724
# 235 / 375 a036420 precision_score :  0.665
# 236 / 375 a036460 precision_score :  0.669
# 237 / 375 a036570 precision_score :  0.713
# 238 / 375 a037270 precision_score :  0.663
# 239 / 375 a037560 precision_score :  0.765
# 240 / 375 a039130 precision_score :  0.623
# 241 / 375 a039490 precision_score :  0.762
# 242 / 375 a042660 precision_score :  0.784
# 243 / 375 a042670 precision_score :  0.68
# 244 / 375 a047040 precision_score :  0.726
# 245 / 375 a047050 precision_score :  0.766
# 246 / 375 a047400 precision_score :  0.613
# 247 / 375 a047810 precision_score :  0.699
# 248 / 375 a051600 precision_score :  0.772
# 249 / 375 a051900 precision_score :  0.718
# 250 / 375 a051910 precision_score :  0.68
# 251 / 375 a052690 precision_score :  0.69
# 252 / 375 a053210 precision_score :  0.647
# 253 / 375 a055490 precision_score :  0.641
# 254 / 375 a055550 precision_score :  0.737
# 255 / 375 a057050 precision_score :  0.814
# 256 / 375 a058850 precision_score :  0.7
# 257 / 375 a058860 precision_score :  0.734
# 258 / 375 a060980 precision_score :  0.638
# 259 / 375 a063160 precision_score :  0.685
# 260 / 375 a064350 precision_score :  0.787
# 261 / 375 a064960 precision_score :  0.66
# 262 / 375 a066570 precision_score :  0.759
# 263 / 375 a068270 precision_score :  0.741
# 264 / 375 a068290 precision_score :  0.746
# 265 / 375 a069260 precision_score :  0.753
# 266 / 375 a069960 precision_score :  0.71
# 267 / 375 a070960 precision_score :  0.73
# 268 / 375 a071050 precision_score :  0.702
# 269 / 375 a071970 precision_score :  0.562
# 270 / 375 a078930 precision_score :  0.674
# 271 / 375 a079430 precision_score :  0.773
# 272 / 375 a079980 precision_score :  0.723
# 273 / 375 a081000 precision_score :  0.736
# 274 / 375 a081660 precision_score :  0.744
# 275 / 375 a082640 precision_score :  0.713
# 276 / 375 a083420 precision_score :  0.777
# 277 / 375 a084010 precision_score :  0.696
# 278 / 375 a084690 precision_score :  0.804
# 279 / 375 a085620 precision_score :  0.791
# 280 / 375 a086280 precision_score :  0.651
# 281 / 375 a086790 precision_score :  0.699
# 282 / 375 a088350 precision_score :  0.682
# 283 / 375 a089590 precision_score :  0.769
# 284 / 375 a090080 precision_score :  0.796
# 285 / 375 a090430 precision_score :  0.69
# 286 / 375 a091810 precision_score :  0.69
# 287 / 375 a092220 precision_score :  0.619
# 288 / 375 a093050 precision_score :  0.784
# 289 / 375 a093230 precision_score :  0.769
# 290 / 375 a093370 precision_score :  0.732
# 291 / 375 a095720 precision_score :  0.647
# 292 / 375 a096770 precision_score :  0.658
# 293 / 375 a100250 precision_score :  0.577
# 294 / 375 a102260 precision_score :  0.661
# 295 / 375 a102460 precision_score :  0.654
# 296 / 375 a103140 precision_score :  0.749
# 297 / 375 a103590 precision_score :  0.694
# 298 / 375 a104700 precision_score :  0.698
# 299 / 375 a105560 precision_score :  0.698
# 300 / 375 a105630 precision_score :  0.756
# 301 / 375 a105840 precision_score :  0.693
# 302 / 375 a108670 precision_score :  0.623
# 303 / 375 a111110 precision_score :  0.875
# 304 / 375 a111770 precision_score :  0.632
# 305 / 375 a112610 precision_score :  0.734
# 306 / 375 a114090 precision_score :  0.792
# 307 / 375 a120110 precision_score :  0.705
# 308 / 375 a122900 precision_score :  0.817
# 309 / 375 a126560 precision_score :  0.695
# 310 / 375 a130660 precision_score :  0.809
# 311 / 375 a138490 precision_score :  0.789
# 312 / 375 a138930 precision_score :  0.686
# 313 / 375 a139130 precision_score :  0.694
# 314 / 375 a139480 precision_score :  0.743
# 315 / 375 a139990 precision_score :  0.734
# 316 / 375 a145210 precision_score :  0.705
# 317 / 375 a145720 precision_score :  0.657
# 318 / 375 a161000 precision_score :  0.7
# 319 / 375 a161890 precision_score :  0.7
# 320 / 375 a170900 precision_score :  0.734
# 321 / 375 a175330 precision_score :  0.748
# 322 / 375 a178920 precision_score :  0.785
# 323 / 375 a180640 precision_score :  0.634
# 324 / 375 a181710 precision_score :  0.729
# 325 / 375 a183190 precision_score :  0.818
# 326 / 375 a185750 precision_score :  0.755
# 327 / 375 a192080 precision_score :  0.672
# 328 / 375 a192400 precision_score :  0.842
# 329 / 375 a192820 precision_score :  0.675
# 330 / 375 a210540 precision_score :  0.784
# 331 / 375 a213500 precision_score :  0.796
# 332 / 375 a214320 precision_score :  0.765
# 333 / 375 a214420 precision_score :  0.567
# 334 / 375 a229640 precision_score :  0.721
# 335 / 375 a234080 precision_score :  0.821
# 336 / 375 a241560 precision_score :  0.572
# 337 / 375 a241590 precision_score :  0.742
# 338 / 375 a244920 precision_score :  0.54
# 339 / 375 a248070 precision_score :  0.64
# 340 / 375 a251270 precision_score :  0.767
# 341 / 375 a259960 precision_score :  0.652
# 342 / 375 a267250 precision_score :  0.69
# 343 / 375 a267260 precision_score :  0.724
# 344 / 375 a267270 precision_score :  0.606
# 345 / 375 a271560 precision_score :  0.727
# 346 / 375 a271980 precision_score :  0.635
# 347 / 375 a272210 precision_score :  0.733
# 348 / 375 a272450 precision_score :  0.737
# 349 / 375 a281820 precision_score :  0.679
# 350 / 375 a282330 precision_score :  0.812
# 351 / 375 a284740 precision_score :  0.739
# 352 / 375 a285130 precision_score :  0.788
# 353 / 375 a286940 precision_score :  0.774
# 354 / 375 a294870 precision_score :  0.718
# 355 / 375 a298020 precision_score :  0.688
# 356 / 375 a298040 precision_score :  0.705
# 357 / 375 a298690 precision_score :  0.65
# 358 / 375 a300720 precision_score :  0.741
# 359 / 375 a302440 precision_score :  0.728
# 360 / 375 a307950 precision_score :  0.746
# 361 / 375 a308170 precision_score :  0.769
# 362 / 375 a316140 precision_score :  0.797
# 363 / 375 a317400 precision_score :  0.66
# 364 / 375 a322000 precision_score :  0.805
# 365 / 375 a323410 precision_score :  0.768
# 366 / 375 a326030 precision_score :  0.689
# 367 / 375 a329180 precision_score :  0.712
# 368 / 375 a344820 precision_score :  0.743
# 369 / 375 a352820 precision_score :  0.598
# 370 / 375 a361610 precision_score :  0.769
# 371 / 375 a372910 precision_score :  0.592
# 372 / 375 a375500 precision_score :  0.752
# 373 / 375 a377300 precision_score :  0.68
# 374 / 375 a383800 precision_score :  0.79
# 0.7105866666666667
#
# C group done
#
# D group start
# 0 / 144 a000060 precision_score :  0.775
# 1 / 144 a000180 precision_score :  0.674
# 2 / 144 a000220 precision_score :  0.573
# 3 / 144 a000400 precision_score :  0.812
# 4 / 144 a000890 precision_score :  0.683
# 5 / 144 a000970 precision_score :  0.794
# 6 / 144 a001060 precision_score :  0.841
# 7 / 144 a001200 precision_score :  0.693
# 8 / 144 a001390 precision_score :  0.7
# 9 / 144 a001500 precision_score :  0.813
# 10 / 144 a001570 precision_score :  0.628
# 11 / 144 a001750 precision_score :  0.788
# 12 / 144 a001790 precision_score :  0.813
# 13 / 144 a001820 precision_score :  0.726
# 14 / 144 a002240 precision_score :  0.785
# 15 / 144 a002360 precision_score :  0.671
# 16 / 144 a002410 precision_score :  0.697
# 17 / 144 a002450 precision_score :  0.812
# 18 / 144 a002630 precision_score :  0.696
# 19 / 144 a002710 precision_score :  0.506
# 20 / 144 a002720 precision_score :  0.657
# 21 / 144 a003060 precision_score :  0.662
# 22 / 144 a003070 precision_score :  0.769
# 23 / 144 a003470 precision_score :  0.753
# 24 / 144 a003520 precision_score :  0.689
# 25 / 144 a003530 precision_score :  0.704
# 26 / 144 a003690 precision_score :  0.721
# 27 / 144 a003960 precision_score :  0.73
# 28 / 144 a004060 precision_score :  0.635
# 29 / 144 a004140 precision_score :  0.609
# 30 / 144 a004360 precision_score :  0.748
# 31 / 144 a004380 precision_score :  0.68
# 32 / 144 a004710 precision_score :  0.642
# 33 / 144 a004720 precision_score :  0.771
# 34 / 144 a004960 precision_score :  0.734
# 35 / 144 a004980 precision_score :  0.621
# 36 / 144 a005180 precision_score :  0.832
# 37 / 144 a005360 precision_score :  0.585
# 38 / 144 a005830 precision_score :  0.696
# 39 / 144 a005930 precision_score :  0.633
# 40 / 144 a006260 precision_score :  0.707
# 41 / 144 a006380 precision_score :  0.577
# 42 / 144 a006740 precision_score :  0.66
# 43 / 144 a006800 precision_score :  0.672
# 44 / 144 a006840 precision_score :  0.654
# 45 / 144 a007280 precision_score :  0.708
# 46 / 144 a007570 precision_score :  0.734
# 47 / 144 a007660 precision_score :  0.649
# 48 / 144 a008060 precision_score :  0.725
# 49 / 144 a008700 precision_score :  0.745
# 50 / 144 a008730 precision_score :  0.596
# 51 / 144 a009310 precision_score :  0.699
# 52 / 144 a009410 precision_score :  0.739
# 53 / 144 a009470 precision_score :  0.68
# 54 / 144 a009580 precision_score :  0.791
# 55 / 144 a009810 precision_score :  0.612
# 56 / 144 a010050 precision_score :  0.746
# 57 / 144 a010600 precision_score :  0.64
# 58 / 144 a010620 precision_score :  0.753
# 59 / 144 a010660 precision_score :  0.607
# 60 / 144 a011280 precision_score :  0.624
# 61 / 144 a011500 precision_score :  0.734
# 62 / 144 a011930 precision_score :  0.712
# 63 / 144 a012160 precision_score :  0.813
# 64 / 144 a012280 precision_score :  0.695
# 65 / 144 a012510 precision_score :  0.686
# 66 / 144 a012800 precision_score :  0.735
# 67 / 144 a013000 precision_score :  0.656
# 68 / 144 a013360 precision_score :  0.639
# 69 / 144 a015020 precision_score :  0.668
# 70 / 144 a015760 precision_score :  0.703
# 71 / 144 a015860 precision_score :  0.713
# 72 / 144 a015890 precision_score :  0.726
# 73 / 144 a016610 precision_score :  0.771
# 74 / 144 a017180 precision_score :  0.585
# 75 / 144 a017900 precision_score :  0.673
# 76 / 144 a018250 precision_score :  0.79
# 77 / 144 a018670 precision_score :  0.82
# 78 / 144 a023800 precision_score :  0.647
# 79 / 144 a024090 precision_score :  0.774
# 80 / 144 a025560 precision_score :  0.698
# 81 / 144 a025820 precision_score :  0.653
# 82 / 144 a025860 precision_score :  0.738
# 83 / 144 a026890 precision_score :  0.79
# 84 / 144 a027740 precision_score :  0.736
# 85 / 144 a028050 precision_score :  0.711
# 86 / 144 a029460 precision_score :  0.758
# 87 / 144 a029780 precision_score :  0.756
# 88 / 144 a030610 precision_score :  0.733
# 89 / 144 a032560 precision_score :  0.739
# 90 / 144 a033270 precision_score :  0.75
# 91 / 144 a033530 precision_score :  0.667
# 92 / 144 a034830 precision_score :  0.685
# 93 / 144 a035510 precision_score :  0.68
# 94 / 144 a036580 precision_score :  0.738
# 95 / 144 a042700 precision_score :  0.651
# 96 / 144 a044450 precision_score :  0.835
# 97 / 144 a053690 precision_score :  0.78
# 98 / 144 a058430 precision_score :  0.654
# 99 / 144 a068400 precision_score :  0.729
# 100 / 144 a069460 precision_score :  0.768
# 101 / 144 a071840 precision_score :  0.748
# 102 / 144 a072130 precision_score :  0.656
# 103 / 144 a073240 precision_score :  0.616
# 104 / 144 a075580 precision_score :  0.776
# 105 / 144 a077500 precision_score :  0.772
# 106 / 144 a077970 precision_score :  0.668
# 107 / 144 a078000 precision_score :  0.835
# 108 / 144 a079160 precision_score :  0.675
# 109 / 144 a079550 precision_score :  0.623
# 110 / 144 a082740 precision_score :  0.66
# 111 / 144 a089470 precision_score :  0.802
# 112 / 144 a091090 precision_score :  0.754
# 113 / 144 a093240 precision_score :  0.572
# 114 / 144 a097520 precision_score :  0.706
# 115 / 144 a097950 precision_score :  0.712
# 116 / 144 a101140 precision_score :  0.676
# 117 / 144 a102280 precision_score :  0.601
# 118 / 144 a115390 precision_score :  0.878
# 119 / 144 a117580 precision_score :  0.606
# 120 / 144 a119650 precision_score :  0.653
# 121 / 144 a123890 precision_score :  0.67
# 122 / 144 a128820 precision_score :  0.614
# 123 / 144 a128940 precision_score :  0.715
# 124 / 144 a137310 precision_score :  0.719
# 125 / 144 a138040 precision_score :  0.657
# 126 / 144 a155660 precision_score :  0.591
# 127 / 144 a161390 precision_score :  0.617
# 128 / 144 a192650 precision_score :  0.774
# 129 / 144 a194370 precision_score :  0.704
# 130 / 144 a195870 precision_score :  0.633
# 131 / 144 a204320 precision_score :  0.687
# 132 / 144 a214330 precision_score :  0.668
# 133 / 144 a214390 precision_score :  0.721
# 134 / 144 a249420 precision_score :  0.601
# 135 / 144 a271940 precision_score :  0.684
# 136 / 144 a282690 precision_score :  0.814
# 137 / 144 a298000 precision_score :  0.631
# 138 / 144 a298050 precision_score :  0.738
# 139 / 144 a336260 precision_score :  0.741
# 140 / 144 a336370 precision_score :  0.665
# 141 / 144 a339770 precision_score :  0.752
# 142 / 144 a363280 precision_score :  0.655
# 143 / 144 a381970 precision_score :  0.658
# 0.7024722222222223
#
# D group done
#
# E group start
# 0 / 16 a000660 precision_score :  0.722
# 1 / 16 a001210 precision_score :  0.531
# 2 / 16 a001470 precision_score :  0.597
# 3 / 16 a003580 precision_score :  0.633
# 4 / 16 a005390 precision_score :  0.648
# 5 / 16 a005690 precision_score :  0.694
# 6 / 16 a007340 precision_score :  0.532
# 7 / 16 a007810 precision_score :  0.579
# 8 / 16 a009440 precision_score :  0.658
# 9 / 16 a028260 precision_score :  0.728
# 10 / 16 a044380 precision_score :  0.707
# 11 / 16 a074610 precision_score :  0.479
# 12 / 16 a089860 precision_score :  0.721
# 13 / 16 a207940 precision_score :  0.623
# 14 / 16 a353200 precision_score :  0.696
# 15 / 16 a402340 precision_score :  0.642
# 0.636875
#
# E group done
# 0.636875

# %%
B_precision_score
# Out:
# 0.6944285714285715

# %%
C_precision_score
# Out:
# 0.7105866666666667

# %%
D_precision_score
# Out:
# 0.7024722222222223

# %%
E_precision_score
# Out:
# 0.636875
